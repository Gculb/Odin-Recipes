# %% [markdown]
# <a href="https://colab.research.google.com/github/Gculb/Odin-Recipes/blob/main/Google_Project_Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np  
import pandas as pd   
import matplotlib as plt 
import descartes
import plotly.express as px

import os

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-fccca455-3def-4131-9689-e6993a411d01" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-fccca455-3def-4131-9689-e6993a411d01">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import io
df = pd.read_csv(io.BytesIO(uploaded['Bike_Data.csv']))

# %%
df.head()
# Out:
#             ride_id  rideable_type started_at  ended_at start_station_name  \
# 0  600CFD130D0FD2A4  electric_bike   17:27:53  17:35:15                NaN
# 1  F5E6B5C1682C6464  electric_bike   18:39:52  18:47:28                NaN
# 2  B6EB6D27BAD771D2  electric_bike   11:49:25  12:02:54                NaN
# 3  C9C320375DE1D5C6  electric_bike   11:15:25  11:19:43                NaN
# 4  56C055851023BE98  electric_bike   23:36:50  23:45:17                NaN
#
#   start_station_id end_station_name end_station_id  start_lat  start_lng  \
# 0              NaN              NaN            NaN      41.89     -87.62
# 1              NaN              NaN            NaN      41.91     -87.62
# 2              NaN              NaN            NaN      41.91     -87.65
# 3              NaN              NaN            NaN      41.80     -87.66
# 4              NaN              NaN            NaN      41.91     -87.63
#
#    end_lat  end_lng member_type trip_time (min)
# ...

# %%
tripTime = df.loc[:,"trip_time (min)"]

# %%
pd.isna(df['trip_time (min)'])
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 769199    False
# 769200    False
# 769201    False
# 769202    False
# 769203    False
# Name: trip_time (min), Length: 769204, dtype: bool

# %%
df.drop(['start_station_name','end_station_name','start_station_id','end_station_id','end_station_id'], axis=1)
# Out:
#                  ride_id  rideable_type started_at  ended_at  start_lat  \
# 0       600CFD130D0FD2A4  electric_bike   17:27:53  17:35:15  41.890000
# 1       F5E6B5C1682C6464  electric_bike   18:39:52  18:47:28  41.910000
# 2       B6EB6D27BAD771D2  electric_bike   11:49:25  12:02:54  41.910000
# 3       C9C320375DE1D5C6  electric_bike   11:15:25  11:19:43  41.800000
# 4       56C055851023BE98  electric_bike   23:36:50  23:45:17  41.910000
# ...                  ...            ...        ...       ...        ...
# 769199  7B3B2890CA85E05D   classic_bike    0:56:48   1:01:39  41.910522
# 769200  1E993989CC66BCBC   classic_bike    0:56:25   1:00:26  41.910522
# 769201  AEA166296BC67566  electric_bike   12:47:12  12:47:36  41.920000
# 769202  B9F527742959CF03   classic_bike   13:28:46  13:53:11  41.884576
# 769203  D241310352E26484   classic_bike   14:40:51  15:08:14  41.857556
#
#         start_lng    end_lat    end_lng member_type trip_time (min)
# ...

# %%
print(df['rideable_type'].value_counts())
# Out:
# classic_bike     406660
# electric_bike    331904
# docked_bike       30640
# Name: rideable_type, dtype: int64

# %%
print(df['member_type'].value_counts())
# Out:
# annual    400153
# casual    369051
# Name: member_type, dtype: int64

# %%
print(df['trip_time (min)'].value_counts(dropna=True))
# Out:
# 0:07:08     772
# 0:05:23     771
# 0:06:38     766
# 0:06:19     766
# 0:05:35     762
#            ...
# 4:01:35       1
# 14:30:01      1
# 4:53:18       1
# 11:45:21      1
# 3:13:17       1
# Name: trip_time (min), Length: 11928, dtype: int64

# %%
print(df.dropna(axis=1, how='all'))
# Out:
#                  ride_id  rideable_type started_at  ended_at  \
# 0       600CFD130D0FD2A4  electric_bike   17:27:53  17:35:15
# 1       F5E6B5C1682C6464  electric_bike   18:39:52  18:47:28
# 2       B6EB6D27BAD771D2  electric_bike   11:49:25  12:02:54
# 3       C9C320375DE1D5C6  electric_bike   11:15:25  11:19:43
# 4       56C055851023BE98  electric_bike   23:36:50  23:45:17
# ...                  ...            ...        ...       ...
# 769199  7B3B2890CA85E05D   classic_bike    0:56:48   1:01:39
# 769200  1E993989CC66BCBC   classic_bike    0:56:25   1:00:26
# 769201  AEA166296BC67566  electric_bike   12:47:12  12:47:36
# 769202  B9F527742959CF03   classic_bike   13:28:46  13:53:11
# 769203  D241310352E26484   classic_bike   14:40:51  15:08:14
#
#                    start_station_name start_station_id  \
# 0                                 NaN              NaN
# 1                                 NaN              NaN
# 2                                 NaN              NaN
# ...

# %%
px.set_mapbox_access_token(open("Bike_Data.csv").read())
fig = px.scatter_mapbox(df,
                        lat=df['start_lat'],
                        lon=df['start_lng'],
                        hover_name = 'start_lat',
                        height = 1000, width = 1000)
fig.show()
